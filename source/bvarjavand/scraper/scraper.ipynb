# %%
from bs4 import BeautifulSoup
import requests

url = "http://m2g.io/"
r  = requests.get(url)
data = r.text

soup = BeautifulSoup(data, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>m2g: reliable human connectomes at scale &amp;vert; m2g @ NeuroData</title>
# <meta content="NeuroData's home for M3RI derived graphs, tools, and services" name="description"/>
# <meta content="mri" name="keywords"/>
# <!-- Open Graph -->
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="m2g: reliable human connectomes at scale" property="og:title"/>
# <meta content="NeuroData's home for M3RI derived graphs, tools, and services" property="og:description"/>
# <meta content="http://docs.neurodata.io/mri.neurodata.io/" property="og:url"/>
# <meta content="m2g @ NeuroData" property="og:site_name"/>
# <meta content="http://docs.neurodata.io/mri.neurodata.io/images/" property="og:image"/>
# <link href="http://docs.neurodata.io/mri.neurodata.io/" rel="canonical"/>
# <link href="http://docs.neurodata.io/mri.neurodata.io/feed.xml" rel="alternate" title="m2g @ NeuroData Feed" type="application/atom+xml"/>
# <!-- http://t.co/dKP3o1e -->
# <meta content="True" name="HandheldFriendly"/>
# <meta content="320" name="MobileOptimized"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="http://fonts.googleapis.com/css?family=Montserrat:400,700|Open+Sans:400,600,300,800,700" rel="stylesheet" type="text/css"/>
# <link href="http://docs.neurodata.io/mri.neurodata.io/assets/css/vendor/font-awesome.min.css" rel="stylesheet"/>
# <link href="http://docs.neurodata.io/mri.neurodata.io/assets/css/vendor/normalize.css" rel="stylesheet"/>
# <link href="http://docs.neurodata.io/mri.neurodata.io/assets/css/vendor/nprogress.css" rel="stylesheet"/>
# <link href="http://docs.neurodata.io/mri.neurodata.io/assets/css/vendor/foundation.min.css" rel="stylesheet"/>
# <link href="http://docs.neurodata.io/mri.neurodata.io/assets/css/style.css" rel="stylesheet"/>
# <link href="http://docs.neurodata.io/mri.neurodata.io/assets/css/post.css" rel="stylesheet"/>
# <script src="https://www.w3schools.com/lib/w3data.js"></script>
# <!-- Icons -->
# <!-- 16x16 -->
# <link href="http://docs.neurodata.io/mri.neurodata.io/favicon.ico" rel="shortcut icon"/>
# <!-- 32x32 -->
# <link href="http://docs.neurodata.io/mri.neurodata.io/favicon.png" rel="shortcut icon"/>
# <!-- 57x57 (precomposed) for iPhone 3GS, pre-2011 iPod Touch and older Android devices -->
# <link href="http://docs.neurodata.io/mri.neurodata.io/images/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
# <!-- 72x72 (precomposed) for 1st generation iPad, iPad 2 and iPad mini -->
# <link href="http://docs.neurodata.io/mri.neurodata.io/images/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <!-- 114x114 (precomposed) for iPhone 4, 4S, 5 and post-2011 iPod Touch -->
# <link href="http://docs.neurodata.io/mri.neurodata.io/images/apple-touch-icon-114x114-precomposed.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <!-- 144x144 (precomposed) for iPad 3rd and 4th generation -->
# <link href="http://docs.neurodata.io/mri.neurodata.io/images/apple-touch-icon-144x144-precomposed.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# </head>
# <body class="home-template" data-spy="scroll" data-target=".navbar-fixed-top" id="page-top" itemscope="" itemtype="http://schema.org/WebPage">
# <header class="notepad-page-header">
# <div class="notepad-page-menu-header">
# <a class="notepad-blog-logo" href="http://docs.neurodata.io/mri.neurodata.io" style="display:inline-block; line-height:80px">
# <img alt="Blog Logo" src="http://docs.neurodata.io/mri.neurodata.io/images/ndmg.png" style="height:80px;padding:10px"/>
# <h3 style="display:inline; color:#318dde">m2g.io</h3>
# </a>
# <span style="float:right; line-height:80px; vertical-align:middle; padding-right:100px">
# <a href="#links">Links</a> |
# <a href="#downloads">Downloads</a> |
# <a href="#references">References</a>
# </span>
# </div>
# </header>
# <main class="notepad-content" role="main">
# <div class="row" style="border-bottom: 0.0625rem solid #d9d9d9; padding-top: 2rem; padding-bottom: 1rem;">
# <img alt="m2g-logo" src="http://docs.neurodata.io/mri.neurodata.io/images/ndmg.png" style="height:80px; padding-right:20px"/> <h2 style="display:inline-block;"> m2g: reliable human connectomes at scale </h2>
# </div>
# <!-- Resources start -->
# <div class="row" style="padding-top: 2rem; padding-bottom: 1rem;">
# <a name="links"></a>
# <h3> Links </h3>
# <div class="small-4 medium-4 large-4 columns">
# <h4> Public-Facing </h4>
# <ul>
# <li> <a href="http://docs.neurodata.io/ndmg-paper/ndmg.pdf"><code>Pipeline and Meganalysis Paper (pre-print)</code></a></li>
# <li> <a href="https://www.dropbox.com/s/xrprdkj0k9rdi1t/ndmg.pdf?dl=0"><code>Pipeline and Meganalysis Presentation</code></a></li>
# <li> <a href="https://hub.docker.com/r/bids/ndmg"><code>Docker Container</code></a></li>
# </ul>
# </div>
# <div class="small-4 medium-4 large-4 columns">
# <h4> Github </h4>
# <ul>
# <li> <a href="https://github.com/neurodata/sic"><code>Science in the Cloud (sic)</code></a></li>
# <li> <a href="https://github.com/neurodata/ndmg"><code>NeuroData's MRI Graphs pipeline (ndmg)</code></a></li>
# <li> <a href="https://github.com/neurodata/ndgrutedb"><code>NeuroData's GRaph with rich attribUTE DataBase (ndgrutedb)</code></a></li>
# </ul>
# </div>
# <div class="small-4 medium-4 large-4 columns">
# <h4> Web Services </h4>
# <ul>
# <li> <a href="http://scienceinthe.cloud"><code>sic</code></a></li>
# <li> <a href="http://openconnecto.me/graph-services/download/"><code>ndgrutedb</code></a></li>
# <li> <a href="http://openconnecto.me/graph-services/c4/"><code>Community Connectomics via Cloud Computing (c4)</code></a></li>
# </ul>
# </div>
# </div>
# <!-- Resources stop -->
# <!-- Downloads start -->
# <a name="downloads"></a>
# <div w3-include-html="https://raw.githubusercontent.com/neurodata/mri.neurodata.io/master/table_dwi.html"></div>
# <div w3-include-html="https://raw.githubusercontent.com/neurodata/mri.neurodata.io/master/table_fmri.html"></div>
# <!-- <div w3-include-html="table_dwi.html"></div>
#  <div w3-include-html="table_fmri.html"></div> -->
# <!-- Downlaods stop -->
# <!-- References start -->
# <div class="row" style="border-bottom: 0rem; padding-top: 2rem; padding-bottom: 1rem;">
# <a name="references"></a>
# <h3> References </h3>
# When using data, figures, or tools shared here, please cite the following:
# <ul>
# <li>Kiar, Gregory, et al. “ndmg: Neurodata's MRI Graphs Pipeline”. Zenodo, August 15, 2016. doi:10.5281/zenodo.60206.</li>
# <li>Gregory Kiar, Krzysztof J. Gorgolewski, Dean Kleissas, William Gray Roncal, Brian Litt,
# 			Brian Wandell, Russel A. Poldrack, Martin Wiener, R. Jacob Vogelstein, Randal Burns, Joshua T.
# 			Vogelstein; Science In the Cloud (SIC): A use case in MRI Connectomics. Gigascience 2017
# 			gix013. doi: <a href="https://doi.org/10.1093/gigascience/gix013" target="_blank">10.1093/gigascience/gix013</a>
# </li>
# <li>
# 			Kiar, G; Gorgolewski, K, J; Kleissas, D; Gray Roncal, W; Litt, B; Wandell, B; Poldrack, R, A;
# 		  Wiener, M; Vogelstein, R, J; Burns, R; Vogelstein, J, T (2017): Example use case of SIC with the
# 			ndmg pipeline (SIC:ndmg) GigaScience Database.
# 			<a href="http://dx.doi.org/10.5524/100285" target="_blank">http://dx.doi.org/10.5524/100285</a>
# </li>
# </ul>
# <h5> Previous Pipeline Papers </h5>
# <ul>
# <li>Gray, William R., et al. "Magnetic resonance connectome automated pipeline: an overview." <em>IEEE pulse</em> 3.2 (2012): 42-48. </li>
# <li>Gray Roncal, William R., et al. "MIGRAINE: MRI graph reliability analysis and inference for connectomics." <em>Global Conference on Signal and Information Processing (GlobalSIP)</em>, 2013 IEEE.</li>
# </ul>
# <h5> Related Papers </h5>
# <ul>
# <li>Mhembere, Disa, et al. "Computing scalable multivariate glocal invariants of large (brain-) graphs." <em>Global Conference on Signal and Information Processing (GlobalSIP)</em>, 2013 IEEE.</li>
# </ul>
# </div>
# <!-- References stop -->
# </main>
# <footer class="notepad-site-footer">
# <div class="copyright">
# <section>All content copyright <a href="http://docs.neurodata.io/mri.neurodata.io/about">Neurodata</a> © 2017 • All rights reserved.</section>
# </div>
# <div class="social-icons">
# <a href="http://github.com/neurodata">
# <span class="fa-stack fa-lg">
# <i class="fa fa-circle fa-stack-2x fa-inverse"></i>
# <i class="fa fa-github fa-stack-1x"></i>
# </span>
# </a>
# <a href="http://facebook.com/neurodata.io">
# <span class="fa-stack fa-lg">
# <i class="fa fa-circle fa-stack-2x fa-inverse"></i>
# <i class="fa fa-facebook fa-stack-1x"></i>
# </span>
# </a>
# </div>
# <div class="cf"></div>
# </footer>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js"></script>
# <script>window.jQuery || document.write('<script src="http://docs.neurodata.io/mri.neurodata.io/assets/js/vendor/jquery-1.11.1.min.js"><\/script>')</script>
# <script src="http://docs.neurodata.io/mri.neurodata.io/assets/js/vendor/modernizr.js"></script>
# <script src="http://docs.neurodata.io/mri.neurodata.io/assets/js/foundation.min.js"></script>
# <script src="http://docs.neurodata.io/mri.neurodata.io/assets/js/notepad.js"></script>
# <script src="http://docs.neurodata.io/mri.neurodata.io/assets/js/scripts.min.js"></script>
# <script src="http://docs.neurodata.io/mri.neurodata.io/assets/js/vendor/nprogress.js"></script>
# <script src="https://use.fontawesome.com/72eacbfadb.js"></script>
# <script>
#       $(document).foundation();
#     </script>
# <script> w3IncludeHTML(); </script>
# <script>NProgress.start();var interval=setInterval(function(){NProgress.inc()},1000);jQuery(window).load(function(){clearInterval(interval);NProgress.done()});jQuery(window).unload(function(){NProgress.start()});</script>
# </body></html>

# %%
#links
#https://raw.githubusercontent.com/neurodata/mri.neurodata.io/master/table_dwi.html
#https://raw.githubusercontent.com/neurodata/mri.neurodata.io/master/table_fmri.html

# %%
url_dwi = "https://raw.githubusercontent.com/neurodata/mri.neurodata.io/master/table_dwi.html"
url_fmri = "https://raw.githubusercontent.com/neurodata/mri.neurodata.io/master/table_fmri.html"
dwi = requests.get(url_dwi).text
fmri = requests.get(url_fmri).text
dwi_soup = BeautifulSoup(dwi, 'html.parser')
fmri_soup = BeautifulSoup(fmri, 'html.parser')
print(dwi_soup)
# Out:
# <div class="row">
# <h3> Downloads </h3>
# <h4> Diffusion MRI </h4>
# </div>
# <table>
# <tr>
# <th>Dataset</th>
# <th style="border-right: dashed 1px #ddd;">Covariates</th>
# <th colspan="5">Processed DWI</th>
# <th>Code</th>
# </tr>
# <tr>
# <td><a href="http://fcon_1000.projects.nitrc.org/indi/CoRR/html/bnu_1.html">BNU1</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/BNU1/BNU1.csv">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td><a href="http://fcon_1000.projects.nitrc.org/indi/CoRR/html/bnu_3.html">BNU3</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/BNU3/BNU3.csv">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td><a href="http://fcon_1000.projects.nitrc.org/indi/CoRR/html/hnu_1.html">HNU1</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/HNU1/HNU1.csv">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td><a href="http://mri.kennedykrieger.org/databases.html#Kirby21">KKI2009</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/KKI2009/KKI2009.csv">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td><a href="#">MRN1313</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="#">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td><a href="http://fcon_1000.projects.nitrc.org/indi/CoRR/html/nki_1.html">NKI1</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/NKI1/NKI1.csv">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td><a href="http://fcon_1000.projects.nitrc.org/indi/enhanced/">NKIENH</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="#">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td><a href="http://fcon_1000.projects.nitrc.org/indi/CoRR/html/swu_4.html">SWU4</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/SWU4/SWU4.csv">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td><a href="#">Templeton114</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/Templeton114/Templeton114.csv">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# <tr>
# <td><a href="#">Templeton255</a></td>
# <td style="border-right: dashed 1px #ddd;"><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/Templeton255/Templeton255.csv">[@csv]</a></td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/reg_dti/">Aligned Images</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/tensors/">Tensors</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/fibers/">Fibers</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/graphs/">Graphs</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/qa/">QA</a></td>
# </tr>
# </table>
# </td>
# <td>
# <table>
# <tr>
# <td><a href="https://github.com/neurodata/ndmg/tree/v0.0.48">v0.0.48</a></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>

# %%
names=[]
links=[]
for td in dwi_soup.find_all('td'):
    name = td.text.strip()
    link = td.find('a')['href']
    if link not in links:
        print(name)
        names.append(name)
        print(link)
        links.append(link)
# Out:
# BNU1
# http://fcon_1000.projects.nitrc.org/indi/CoRR/html/bnu_1.html
# [@csv]
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/BNU1/BNU1.csv
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/qa/
# v0.0.48
# https://github.com/neurodata/ndmg/tree/v0.0.48
# BNU3
# http://fcon_1000.projects.nitrc.org/indi/CoRR/html/bnu_3.html
# [@csv]
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/BNU3/BNU3.csv
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/qa/
# HNU1
# http://fcon_1000.projects.nitrc.org/indi/CoRR/html/hnu_1.html
# [@csv]
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/HNU1/HNU1.csv
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/qa/
# KKI2009
# http://mri.kennedykrieger.org/databases.html#Kirby21
# [@csv]
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/KKI2009/KKI2009.csv
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/qa/
# MRN1313
# #
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/qa/
# NKI1
# http://fcon_1000.projects.nitrc.org/indi/CoRR/html/nki_1.html
# [@csv]
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/NKI1/NKI1.csv
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/qa/
# NKIENH
# http://fcon_1000.projects.nitrc.org/indi/enhanced/
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/qa/
# SWU4
# http://fcon_1000.projects.nitrc.org/indi/CoRR/html/swu_4.html
# [@csv]
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/SWU4/SWU4.csv
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/qa/
# [@csv]
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/Templeton114/Templeton114.csv
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/qa/
# [@csv]
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/Templeton255/Templeton255.csv
# Aligned Images
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/reg_dti/
# Tensors
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/tensors/
# Fibers
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/fibers/
# Graphs
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/graphs/
# QA
# http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/qa/

# %%
scrapes = []
for i in range(len(names)):
    scrape = {}
    scrape['name'] = names[i]
    scrape['link'] = links[i]
    scrapes.append(scrape)

# %%
for scrape in scrapes:
    print(scrape)
    if 's3' in scrape['link'] and '.csv' not in scrape['link']:
        print(scrape['name'])
        soup = BeautifulSoup(requests.get(scrape['link']).text, 'lxml')
        print(soup)
# Out:
# {'name': 'BNU1', 'link': 'http://fcon_1000.projects.nitrc.org/indi/CoRR/html/bnu_1.html'}
# {'name': '[@csv]', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/BNU1/BNU1.csv'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'v0.0.48', 'link': 'https://github.com/neurodata/ndmg/tree/v0.0.48'}
# {'name': 'BNU3', 'link': 'http://fcon_1000.projects.nitrc.org/indi/CoRR/html/bnu_3.html'}
# {'name': '[@csv]', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/BNU3/BNU3.csv'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU3/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'HNU1', 'link': 'http://fcon_1000.projects.nitrc.org/indi/CoRR/html/hnu_1.html'}
# {'name': '[@csv]', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/HNU1/HNU1.csv'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/HNU1/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'KKI2009', 'link': 'http://mri.kennedykrieger.org/databases.html#Kirby21'}
# {'name': '[@csv]', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/KKI2009/KKI2009.csv'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/KKI2009/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'MRN1313', 'link': '#'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/MRN1313/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'NKI1', 'link': 'http://fcon_1000.projects.nitrc.org/indi/CoRR/html/nki_1.html'}
# {'name': '[@csv]', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/NKI1/NKI1.csv'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKI1/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'NKIENH', 'link': 'http://fcon_1000.projects.nitrc.org/indi/enhanced/'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/NKIENH/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'SWU4', 'link': 'http://fcon_1000.projects.nitrc.org/indi/CoRR/html/swu_4.html'}
# {'name': '[@csv]', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/SWU4/SWU4.csv'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/SWU4/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': '[@csv]', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/Templeton114/Templeton114.csv'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton114/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': '[@csv]', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/data/Templeton255/Templeton255.csv'}
# {'name': 'Aligned Images', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/reg_dti/'}
# Aligned Images
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Tensors', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/tensors/'}
# Tensors
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Fibers', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/fibers/'}
# Fibers
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'Graphs', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/graphs/'}
# Graphs
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>
#
# {'name': 'QA', 'link': 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/Templeton255/ndmg_0-0-48/qa/'}
# QA
# <!DOCTYPE html>
# <html>
# <head>
# <title>MR-NeuroData</title>
# </head>
# <body>
# <!-- <div id="navigation"></div> -->
# <div id="listing"></div>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js" type="text/javascript"></script>
# </body>
# </html>

# %%
url = 'http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/reg_dti/'

# %% [markdown]
# ### Ditch PyQt5 since it has poor mac support, use Selenium

# %%
'''
import sys  
from PyQt4.QtGui import *  
from PyQt4.QtCore import *  
from PyQt4.QtWebKit import *  
from lxml import html 

#Take this class for granted.Just use result of rendering.
class Render(QWebPage):  
  def __init__(self, url):  
    self.app = QApplication(sys.argv)  
    QWebPage.__init__(self)  
    self.loadFinished.connect(self._loadFinished)  
    self.mainFrame().load(QUrl(url))  
    self.app.exec_()  
  
  def _loadFinished(self, result):  
    self.frame = self.mainFrame()  
    self.app.quit()  

url = 'http://pycoders.com/archive/'  
r = Render(url)  
result = r.frame.toHtml()
#This step is important.Converting QString to Ascii for lxml to process
archive_links = html.fromstring(str(result.toAscii()))
print(archive_links)
'''
# Out:
# "\nimport sys  \nfrom PyQt4.QtGui import *  \nfrom PyQt4.QtCore import *  \nfrom PyQt4.QtWebKit import *  \nfrom lxml import html \n\n#Take this class for granted.Just use result of rendering.\nclass Render(QWebPage):  \n  def __init__(self, url):  \n    self.app = QApplication(sys.argv)  \n    QWebPage.__init__(self)  \n    self.loadFinished.connect(self._loadFinished)  \n    self.mainFrame().load(QUrl(url))  \n    self.app.exec_()  \n  \n  def _loadFinished(self, result):  \n    self.frame = self.mainFrame()  \n    self.app.quit()  \n\nurl = 'http://pycoders.com/archive/'  \nr = Render(url)  \nresult = r.frame.toHtml()\n#This step is important.Converting QString to Ascii for lxml to process\narchive_links = html.fromstring(str(result.toAscii()))\nprint(archive_links)\n"

# %%
import time
from selenium import webdriver

browser = webdriver.Chrome()
browser.get('http://mrneurodata.s3-website-us-east-1.amazonaws.com/BNU1/ndmg_0-0-48/reg_dti/') #navigate to the page
time.sleep(.5) #wait for .5 seconds(kind of jank)
innerHTML = browser.execute_script("return document.body.innerHTML") #returns the inner HTML as a string
browser.close()
print(innerHTML)
# Out:
#   <!-- <div id="navigation"></div> -->
#   <div id="listing"><pre>Last Modified                   Size           Key
# ---------------------------------------------------------------------------------------------
#                                                <a href="../">../</a>
# 2017-03-07T21:58:23.000Z        163.1 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025864_ses-1_dwi_aligned.nii.gz">sub-0025864_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:34:18.000Z        164.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025864_ses-2_dwi_aligned.nii.gz">sub-0025864_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:46:05.000Z        161.1 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025865_ses-1_dwi_aligned.nii.gz">sub-0025865_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:09:07.000Z        161.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025865_ses-2_dwi_aligned.nii.gz">sub-0025865_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:17:25.000Z        164.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025866_ses-1_dwi_aligned.nii.gz">sub-0025866_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:11:03.000Z        164.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025866_ses-2_dwi_aligned.nii.gz">sub-0025866_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:59:35.000Z        163.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025867_ses-1_dwi_aligned.nii.gz">sub-0025867_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:37:41.000Z        160.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025867_ses-2_dwi_aligned.nii.gz">sub-0025867_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:05:50.000Z        164.1 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025868_ses-1_dwi_aligned.nii.gz">sub-0025868_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:57:00.000Z        159.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025868_ses-2_dwi_aligned.nii.gz">sub-0025868_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:02:57.000Z        159.7 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025869_ses-1_dwi_aligned.nii.gz">sub-0025869_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:02:33.000Z        158.7 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025869_ses-2_dwi_aligned.nii.gz">sub-0025869_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:37:28.000Z        163.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025870_ses-1_dwi_aligned.nii.gz">sub-0025870_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:48:33.000Z        165.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025870_ses-2_dwi_aligned.nii.gz">sub-0025870_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:55:08.000Z        159.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025871_ses-1_dwi_aligned.nii.gz">sub-0025871_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:08:04.000Z        159.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025871_ses-2_dwi_aligned.nii.gz">sub-0025871_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:55:47.000Z        164.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025872_ses-1_dwi_aligned.nii.gz">sub-0025872_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:52:27.000Z        163.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025872_ses-2_dwi_aligned.nii.gz">sub-0025872_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:46:03.000Z        165.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025873_ses-1_dwi_aligned.nii.gz">sub-0025873_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:00:08.000Z        162.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025873_ses-2_dwi_aligned.nii.gz">sub-0025873_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:59:51.000Z        160.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025874_ses-1_dwi_aligned.nii.gz">sub-0025874_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:10:20.000Z        158.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025874_ses-2_dwi_aligned.nii.gz">sub-0025874_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:02:31.000Z        171.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025875_ses-1_dwi_aligned.nii.gz">sub-0025875_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:01:45.000Z        168.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025875_ses-2_dwi_aligned.nii.gz">sub-0025875_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:08:14.000Z        163.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025876_ses-1_dwi_aligned.nii.gz">sub-0025876_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T23:22:05.000Z        161.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025876_ses-2_dwi_aligned.nii.gz">sub-0025876_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:54:23.000Z        157.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025877_ses-1_dwi_aligned.nii.gz">sub-0025877_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T23:59:53.000Z        158.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025877_ses-2_dwi_aligned.nii.gz">sub-0025877_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:53:43.000Z        161.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025878_ses-1_dwi_aligned.nii.gz">sub-0025878_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:07:25.000Z        161.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025878_ses-2_dwi_aligned.nii.gz">sub-0025878_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:07:59.000Z        162.7 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025879_ses-1_dwi_aligned.nii.gz">sub-0025879_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T23:54:41.000Z        162.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025879_ses-2_dwi_aligned.nii.gz">sub-0025879_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T23:56:33.000Z        166.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025880_ses-1_dwi_aligned.nii.gz">sub-0025880_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:47:15.000Z        163.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025880_ses-2_dwi_aligned.nii.gz">sub-0025880_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:05:01.000Z        168.1 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025881_ses-1_dwi_aligned.nii.gz">sub-0025881_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:05:32.000Z        165.1 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025881_ses-2_dwi_aligned.nii.gz">sub-0025881_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:53:42.000Z        162.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025882_ses-1_dwi_aligned.nii.gz">sub-0025882_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:57:58.000Z        164.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025882_ses-2_dwi_aligned.nii.gz">sub-0025882_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:04:52.000Z        160.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025883_ses-1_dwi_aligned.nii.gz">sub-0025883_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:53:35.000Z        162.7 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025883_ses-2_dwi_aligned.nii.gz">sub-0025883_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:00:51.000Z        161.3 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025884_ses-1_dwi_aligned.nii.gz">sub-0025884_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:09:38.000Z        161.3 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025884_ses-2_dwi_aligned.nii.gz">sub-0025884_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:56:01.000Z        161.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025885_ses-1_dwi_aligned.nii.gz">sub-0025885_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:59:26.000Z        159.7 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025885_ses-2_dwi_aligned.nii.gz">sub-0025885_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:54:16.000Z        161.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025886_ses-1_dwi_aligned.nii.gz">sub-0025886_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:53:12.000Z        159.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025886_ses-2_dwi_aligned.nii.gz">sub-0025886_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:58:30.000Z        165.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025887_ses-1_dwi_aligned.nii.gz">sub-0025887_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T23:38:22.000Z        162.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025887_ses-2_dwi_aligned.nii.gz">sub-0025887_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:08:45.000Z        159.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025888_ses-1_dwi_aligned.nii.gz">sub-0025888_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:03:41.000Z        163.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025888_ses-2_dwi_aligned.nii.gz">sub-0025888_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:04:34.000Z        168.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025889_ses-1_dwi_aligned.nii.gz">sub-0025889_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:53:48.000Z        168.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025889_ses-2_dwi_aligned.nii.gz">sub-0025889_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T23:30:02.000Z        168.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025890_ses-1_dwi_aligned.nii.gz">sub-0025890_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:57:20.000Z        161.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025890_ses-2_dwi_aligned.nii.gz">sub-0025890_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:54:54.000Z        159.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025891_ses-1_dwi_aligned.nii.gz">sub-0025891_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:58:18.000Z        160.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025891_ses-2_dwi_aligned.nii.gz">sub-0025891_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:00:37.000Z        170.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025892_ses-1_dwi_aligned.nii.gz">sub-0025892_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:10:58.000Z        169.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025892_ses-2_dwi_aligned.nii.gz">sub-0025892_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:59:22.000Z        157.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025893_ses-1_dwi_aligned.nii.gz">sub-0025893_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T23:56:17.000Z        158.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025893_ses-2_dwi_aligned.nii.gz">sub-0025893_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:59:21.000Z        156.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025894_ses-1_dwi_aligned.nii.gz">sub-0025894_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T23:56:18.000Z        160.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025894_ses-2_dwi_aligned.nii.gz">sub-0025894_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:56:42.000Z        164.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025895_ses-1_dwi_aligned.nii.gz">sub-0025895_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:03:51.000Z        167.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025895_ses-2_dwi_aligned.nii.gz">sub-0025895_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-08T00:01:09.000Z        162.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025896_ses-1_dwi_aligned.nii.gz">sub-0025896_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:01:33.000Z        167.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025896_ses-2_dwi_aligned.nii.gz">sub-0025896_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T21:58:57.000Z        168.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025897_ses-1_dwi_aligned.nii.gz">sub-0025897_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:01:29.000Z        165.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025897_ses-2_dwi_aligned.nii.gz">sub-0025897_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:06:39.000Z        165.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025898_ses-1_dwi_aligned.nii.gz">sub-0025898_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:09:19.000Z        162.3 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025898_ses-2_dwi_aligned.nii.gz">sub-0025898_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:03:25.000Z        166.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025899_ses-1_dwi_aligned.nii.gz">sub-0025899_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:05:59.000Z        162.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025899_ses-2_dwi_aligned.nii.gz">sub-0025899_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:03:14.000Z        169.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025900_ses-1_dwi_aligned.nii.gz">sub-0025900_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:05:15.000Z        165.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025900_ses-2_dwi_aligned.nii.gz">sub-0025900_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:07:24.000Z        163.3 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025901_ses-1_dwi_aligned.nii.gz">sub-0025901_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T23:17:22.000Z        164.3 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025901_ses-2_dwi_aligned.nii.gz">sub-0025901_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T23:54:36.000Z        167.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025902_ses-1_dwi_aligned.nii.gz">sub-0025902_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T23:15:42.000Z        166.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025902_ses-2_dwi_aligned.nii.gz">sub-0025902_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:04:37.000Z        164.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025903_ses-1_dwi_aligned.nii.gz">sub-0025903_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:03:06.000Z        162.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025903_ses-2_dwi_aligned.nii.gz">sub-0025903_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:06:23.000Z        162.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025904_ses-1_dwi_aligned.nii.gz">sub-0025904_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:56:35.000Z        163.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025904_ses-2_dwi_aligned.nii.gz">sub-0025904_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:08:55.000Z        158.3 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025905_ses-1_dwi_aligned.nii.gz">sub-0025905_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:05:02.000Z        157.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025905_ses-2_dwi_aligned.nii.gz">sub-0025905_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T23:51:04.000Z        161.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025906_ses-1_dwi_aligned.nii.gz">sub-0025906_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:59:56.000Z        161.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025906_ses-2_dwi_aligned.nii.gz">sub-0025906_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:09:01.000Z        171.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025907_ses-1_dwi_aligned.nii.gz">sub-0025907_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:06:39.000Z        169.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025907_ses-2_dwi_aligned.nii.gz">sub-0025907_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:06:05.000Z        168.7 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025908_ses-1_dwi_aligned.nii.gz">sub-0025908_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:01:51.000Z        166.8 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025908_ses-2_dwi_aligned.nii.gz">sub-0025908_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:07:11.000Z        165.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025909_ses-1_dwi_aligned.nii.gz">sub-0025909_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:08:30.000Z        165.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025909_ses-2_dwi_aligned.nii.gz">sub-0025909_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T23:10:56.000Z        158.1 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025910_ses-1_dwi_aligned.nii.gz">sub-0025910_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:05:08.000Z        161.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025910_ses-2_dwi_aligned.nii.gz">sub-0025910_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:01:11.000Z        168.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025911_ses-1_dwi_aligned.nii.gz">sub-0025911_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:02:07.000Z        166.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025911_ses-2_dwi_aligned.nii.gz">sub-0025911_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:08:38.000Z        159.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025912_ses-1_dwi_aligned.nii.gz">sub-0025912_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:09:10.000Z        159.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025912_ses-2_dwi_aligned.nii.gz">sub-0025912_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T23:45:13.000Z        157.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025913_ses-1_dwi_aligned.nii.gz">sub-0025913_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T21:42:18.000Z        101.1 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025913_ses-2_dwi_aligned.nii.gz">sub-0025913_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:05:04.000Z        163.7 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025914_ses-1_dwi_aligned.nii.gz">sub-0025914_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:08:56.000Z        169.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025914_ses-2_dwi_aligned.nii.gz">sub-0025914_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T23:56:39.000Z        167.4 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025915_ses-1_dwi_aligned.nii.gz">sub-0025915_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:09:55.000Z        166.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025915_ses-2_dwi_aligned.nii.gz">sub-0025915_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:06:07.000Z        163.3 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025916_ses-1_dwi_aligned.nii.gz">sub-0025916_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:09:16.000Z        165.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025916_ses-2_dwi_aligned.nii.gz">sub-0025916_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:06:56.000Z        164.2 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025917_ses-1_dwi_aligned.nii.gz">sub-0025917_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:07:43.000Z        168.3 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025917_ses-2_dwi_aligned.nii.gz">sub-0025917_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:08:02.000Z        163.5 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025918_ses-1_dwi_aligned.nii.gz">sub-0025918_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:56:02.000Z        165.0 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025918_ses-2_dwi_aligned.nii.gz">sub-0025918_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:11:37.000Z        168.9 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025919_ses-1_dwi_aligned.nii.gz">sub-0025919_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T23:39:46.000Z        163.6 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025919_ses-2_dwi_aligned.nii.gz">sub-0025919_ses-2_dwi_aligned.nii.gz</a>
# 2017-03-07T22:11:13.000Z        156.3 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025920_ses-1_dwi_aligned.nii.gz">sub-0025920_ses-1_dwi_aligned.nii.gz</a>
# 2017-03-07T22:11:57.000Z        157.7 MB       <a href="https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025920_ses-2_dwi_aligned.nii.gz">sub-0025920_ses-2_dwi_aligned.nii.gz</a>
# </pre></div>
#
# <script type="text/javascript" src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js"></script>
# <script type="text/javascript">
#   var S3BL_IGNORE_PATH = false;
#   var BUCKET_URL = 'https://mrneurodata.s3.amazonaws.com';
#   var S3B_ROOT_DIR = 'data/';
#   var S3B_SORT = 'Z2A';
# </script>
# <script type="text/javascript" src="https://cdn.rawgit.com/gkiar/a0e79ba5362528739dadb5d92bde86d9/raw/289427e3613048a418b5ac57276e060ff3a02c7f/list.js"></script>

# %%
inner_soup = BeautifulSoup(innerHTML, 'lxml')

# %%
data_links = inner_soup.find_all('a')
for link in data_links:
    if 's3' in link['href']:
        print(link['href'])
# Out:
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025864_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025864_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025865_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025865_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025866_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025866_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025867_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025867_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025868_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025868_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025869_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025869_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025870_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025870_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025871_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025871_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025872_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025872_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025873_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025873_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025874_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025874_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025875_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025875_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025876_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025876_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025877_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025877_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025878_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025878_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025879_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025879_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025880_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025880_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025881_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025881_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025882_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025882_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025883_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025883_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025884_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025884_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025885_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025885_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025886_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025886_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025887_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025887_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025888_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025888_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025889_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025889_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025890_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025890_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025891_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025891_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025892_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025892_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025893_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025893_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025894_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025894_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025895_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025895_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025896_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025896_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025897_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025897_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025898_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025898_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025899_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025899_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025900_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025900_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025901_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025901_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025902_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025902_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025903_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025903_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025904_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025904_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025905_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025905_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025906_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025906_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025907_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025907_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025908_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025908_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025909_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025909_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025910_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025910_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025911_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025911_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025912_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025912_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025913_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025913_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025914_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025914_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025915_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025915_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025916_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025916_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025917_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025917_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025918_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025918_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025919_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025919_ses-2_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025920_ses-1_dwi_aligned.nii.gz
# https://mrneurodata.s3.amazonaws.com/data/BNU1/ndmg_0-0-48/reg_dti/sub-0025920_ses-2_dwi_aligned.nii.gz
