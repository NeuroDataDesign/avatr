# %%
import matplotlib.pyplot as plt
import pickle

# %%
metacube = pickle.load(open('metacube.pickle','rb'))

# %%
print metacube['metadata']
# Out:
# {'dim': [[0, 5], [0, 1000], [0, 1000]], 'id': '01_00_00', 'annotaters': []}

# %%
plt.imshow(metacube['data'][4,:,:])
plt.show()

# %%
metacube['metadata']['id']
# Out:
# '01_00_00'
